# %% [markdown]
# # Libraries

# %%
import pandas as pd
from openai import OpenAI
import tiktoken
import tqdm
API_KEY = '<KEY>'
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# %% [markdown]
# # Load Data

# %%
comments = pd.read_csv('Data/comments.csv')
comments['Date'] = pd.to_datetime(comments['Date'])
comments = comments.sort_values(by=['Date', 'UnitCode'], ascending=[True, True]).reset_index(drop=True)
comments['Year'] = comments['Date'].dt.year
comments['MonthName'] = comments['Date'].dt.month_name()
comments['MonthNumber'] = comments['Date'].dt.month

display(comments)
# Out:
#       UnitCode                              ParkName       Date  \
# 0         WORI                    Women's Rights NHP 1993-01-01
# 1         WORI                    Women's Rights NHP 1993-02-01
# 2         WORI                    Women's Rights NHP 1993-03-01
# 3         WORI                    Women's Rights NHP 1993-07-01
# 4         WORI                    Women's Rights NHP 1993-08-01
# ...        ...                                   ...        ...
# 34857     WORI                    Women's Rights NHP 2024-03-01
# 34858     WUPA                            Wupatki NM 2024-03-01
# 34859     ZION                               Zion NP 2024-03-01
# 34860     CHRI                     Christiansted NHS 2024-04-01
# 34861     SARI  Salt River Bay NHP & Ecological Pres 2024-04-01
#
#                                                 Comments  Year MonthName  \
# 0                 Closed New Year's Day Two days at zero  1993   January
# 1      Closed 2/13 at 4p.m. due to Blizzard Two days ...  1993  February
# 2      Park Closed from 12:00 on 3/13 to 3/15 due to ...  1993     March
# 3      Grand Opening of new Wesleyan Chapel Block hel...  1993      July
# 4      Grand Opening of new Wesleyan Chapel Block hel...  1993    August
# ...                                                  ...   ...       ...
# 34857  Visitor Center and Chapel are closed on Sunday...  2024     March
# 34858  3/15/24 - Closed due to inclement weather. 3/3...  2024     March
# 34859  South Campground closed for construction until...  2024     March
# 34860  on site education 1. 4/5 PR JROTC Cadets CHRI ...  2024     April
# 34861  1. 4/17 Alfredo Andrews OOFK SARI - 43 student...  2024     April
#
#        MonthNumber
# 0                1
# 1                2
# 2                3
# 3                7
# 4                8
# ...            ...
# 34857            3
# 34858            3
# 34859            3
# 34860            4
# 34861            4
#
# [34862 rows x 7 columns]

# %% [markdown]
# # Helper Functions

# %%
def formatComment(unitCode: str = None, year: int = None, month: int = None):
    data = comments[(comments['UnitCode'] == unitCode) & (comments['Year'] == year) & (comments['MonthNumber'] == month)]
    if data.empty:
        return 'No comments found'
    formatted = 'Comment for ' + data['MonthName'].iloc[0] + ':\n' + data['Comments'].iloc[0]
    return formatted
def createPrompt(unitCode: str = None, year: int = None, month: int = None):
    comments = formatComment(unitCode, year, month)
    return f"{openai_prompt}\n\n{comments}"
def countTokens(prompt: str):
    return len(encoding.encode(prompt))

openai_prompt = "Your task is to review some comments written by National Park data collectors to describe the visitation at their park for a given month. Analyze the comments and identify any months where specific locations were reported as closed. Your response should be 1-2 concise sentences. If no closures are mentioned, please respond with '<Month Name>: No Closures.'. Do not mention locations that are marked as using averages or estimates. Do not include closures that only happened for a few days or temporary closures due to weather or holidays. If you are unsure, default to no closures. The format should be as follows:\n<Month Name>: <1-2 concise sentence summary of closures>."

openai_prompt_tokens = countTokens(openai_prompt)
print(openai_prompt_tokens)
# Out:
# 134

# %% [markdown]
# # Compile Comments Database For Training

# %%
commentsDataBase = comments.copy()
commentsDataBase['Prompt'] = commentsDataBase.apply(lambda x: formatComment(x['UnitCode'], x['Year'], x['MonthNumber']), axis=1)
display(commentsDataBase)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 commentsDataBase = comments.copy()
# ----> 2 commentsDataBase['Prompt'] = commentsDataBase.apply(lambda x: formatComment(x['UnitCode'], x['Year'], x['MonthNumber']), axis=1)
#       3 display(commentsDataBase)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[32], line 2, in <lambda>(x)
#       1 commentsDataBase = comments.copy()
# ----> 2 commentsDataBase['Prompt'] = commentsDataBase.apply(lambda x: formatComment(x['UnitCode'], x['Year'], x['MonthNumber']), axis=1)
#       3 display(commentsDataBase)
#
# Cell In[31], line 2, in formatComment(unitCode, year, month)
#       1 def formatComment(unitCode: str = None, year: int = None, month: int = None):
# ----> 2     data = comments[(comments['UnitCode'] == unitCode) & (comments['Year'] == year) & (comments['MonthNumber'] == month)]
#       3     if data.empty:
#       4         return 'No comments found'
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/anaconda3/envs/main/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
commentsDataBase['Prompt'][0]
# Out:
# "Comment for January:\nClosed New Year's Day Two days at zero"

# %%
commentsDataBase['WordCount'] = commentsDataBase['Prompt'].apply(lambda x: len(x.split()))
commentsDataBase['TokenCount'] = commentsDataBase['Prompt'].apply(lambda x: countTokens(x))
commentsDataBase['CharacterCount'] = commentsDataBase['Prompt'].apply(lambda x: len(x))
commentsDataBase.sort_values(by=['TokenCount'], ascending=[True], inplace=True)
commentsDataBase.reset_index(drop=True, inplace=True)
display(commentsDataBase)
commentsDataBase.to_csv('Data/comments_with_prompts.csv', index=False)
# Out:
#       UnitCode                           ParkName       Date  \
# 0         RICH                       Richmond NBP 2020-09-01
# 1         DRTO                    Dry Tortugas NP 2023-06-01
# 2         GOGA                    Golden Gate NRA 2020-08-01
# 3         LYBA  LBJ Memorial Grove on the Potomac 2012-08-01
# 4         GOGA                    Golden Gate NRA 2020-09-01
# ...        ...                                ...        ...
# 34857     GRSM           Great Smoky Mountains NP 2023-08-01
# 34858     SARA                       Saratoga NHP 2022-10-01
# 34859     SARA                       Saratoga NHP 2022-09-01
# 34860     WORI                 Women's Rights NHP 2004-07-01
# 34861     WORI                 Women's Rights NHP 2008-10-01
#
#                                                 Comments  Year  MonthName  \
# 0                                                  COVID  2020  September
# 1                                                      .  2023       June
# 2                                                  COVID  2020     August
# 3                                              Estimated  2012     August
# 4                                                  COVID  2020  September
# ...                                                  ...   ...        ...
# 34857  Abrams Creek - Counter malfunctioning, used 20...  2023     August
# 34858  2022 October – Explanatory  Unusual factors: 1...  2022    October
# 34859  2022 September – Explanatory  Unusual factors:...  2022  September
# 34860  July, 2005 was an exceedingly hot month, with ...  2004       July
# 34861  2-Oct: Tubman School- 2 students, 2 adults CH/...  2008    October
#
#        MonthNumber                                             Prompt  \
# 0                9                      Comment for September:\nCOVID
# 1                6                               Comment for June:\n.
# 2                8                         Comment for August:\nCOVID
# 3                8                     Comment for August:\nEstimated
# 4                9                      Comment for September:\nCOVID
# ...            ...                                                ...
# 34857            8  Comment for August:\nAbrams Creek - Counter ma...
# 34858           10  Comment for October:\n2022 October – Explanato...
# 34859            9  Comment for September:\n2022 September – Expla...
# 34860            7  Comment for July:\nJuly, 2005 was an exceeding...
# 34861           10  Comment for October:\n2-Oct: Tubman School- 2 ...
#
#        WordCount  TokenCount  CharacterCount
# 0              4           5              28
# 1              4           5              19
# 2              4           5              25
# 3              4           5              29
# 4              4           5              28
# ...          ...         ...             ...
# 34857        312         478            1924
# 34858        299         482            1924
# 34859        322         498            2019
# 34860        294         500            1830
# 34861        232         567            1620
#
# [34862 rows x 11 columns]

# %%
print(commentsDataBase['WordCount'].max())
# Out:
# 322

# %%
print(commentsDataBase['TokenCount'].sum())
# Out:
# 1468147

# %% [markdown]
# # Filter and Sample Data For Training

# %%
# Filter down data
commentsDataBaseFiltered = commentsDataBase[commentsDataBase['TokenCount'] < 300].reset_index(drop=True) # Remove comments that are too long
display(commentsDataBaseFiltered)
# Out:
#       UnitCode                 ParkName       Date  \
# 0         RICH             Richmond NBP 2020-09-01
# 1         RICH             Richmond NBP 2021-08-01
# 2         RICH             Richmond NBP 2022-01-01
# 3         RICH             Richmond NBP 2021-11-01
# 4         JOFI      John F. Kennedy NHS 2006-10-01
# ...        ...                      ...        ...
# 34732     ROMO        Rocky Mountain NP 2019-01-01
# 34733     NATC              Natchez NHP 2007-06-01
# 34734     SARA             Saratoga NHP 2024-01-01
# 34735     JECA            Jewel Cave NM 2014-08-01
# 34736     WABA  Washita Battlefield NHS 2009-09-01
#
#                                                 Comments  Year  MonthName  \
# 0                                                  COVID  2020  September
# 1                                                  COVID  2021     August
# 2                                                  COVID  2022    January
# 3                                                  COVID  2021   November
# 4                                                 Closed  2006    October
# ...                                                  ...   ...        ...
# 34732  The U.S. Government experienced a shutdown fro...  2019    January
# 34733  Special Program one is Junior Ranger History C...  2007       June
# 34734  2024 January – Explanatory  General: 1. Non-au...  2024    January
# 34735  Elevator #1 experienced a blown fuse at around...  2014     August
# 34736  \t\tWe had 3 Offsite programs this month: Okla...  2009  September
#
#        MonthNumber                                             Prompt  \
# 0                9                      Comment for September:\nCOVID
# 1                8                         Comment for August:\nCOVID
# 2                1                        Comment for January:\nCOVID
# 3               11                       Comment for November:\nCOVID
# 4               10                       Comment for October:\nClosed
# ...            ...                                                ...
# 34732            1  Comment for January:\nThe U.S. Government expe...
# 34733            6  Comment for June:\nSpecial Program one is Juni...
# 34734            1  Comment for January:\n2024 January – Explanato...
# 34735            8  Comment for August:\nElevator #1 experienced a...
# 34736            9  Comment for September:\n\t\tWe had 3 Offsite p...
#
#        WordCount  TokenCount  CharacterCount
# 0              4           5              28
# 1              4           5              25
# 2              4           5              26
# 3              4           5              27
# 4              4           5              27
# ...          ...         ...             ...
# 34732        223         294            1397
# 34733        211         295            1233
# 34734        182         296            1151
# 34735        181         296            1107
# 34736        180         298            1063
#
# [34737 rows x 11 columns]

# %%
# randomly sample 100 unit codes
import random
unitCodesSample = commentsDataBaseFiltered['UnitCode'].unique()
unitCodesSample = random.sample(list(unitCodesSample), 100)
sample = []
for code in unitCodesSample:
    df = commentsDataBaseFiltered[commentsDataBaseFiltered['UnitCode'] == code]
    # randomly sample 3 years
    years = df['Year'].unique()
    if len(years) < 3:
        sample.append(df)
    else:
        years = random.sample(list(years), 3)
        sample.append(df[df['Year'].isin(years)])
sample = pd.DataFrame(pd.concat(sample)).reset_index(drop=True)
sample
# Out:
#      UnitCode              ParkName       Date  \
# 0        WWIM  World War I Memorial 2021-04-01
# 1        LIBO  Lincoln Boyhood NMEM 2013-10-01
# 2        LIBO  Lincoln Boyhood NMEM 2008-09-01
# 3        LIBO  Lincoln Boyhood NMEM 2018-12-01
# 4        LIBO  Lincoln Boyhood NMEM 2008-06-01
# ...       ...                   ...        ...
# 1585     LEWI     Lewis & Clark NHP 2017-12-01
# 1586     LEWI     Lewis & Clark NHP 2017-10-01
# 1587     LEWI     Lewis & Clark NHP 2005-06-01
# 1588     LEWI     Lewis & Clark NHP 2017-08-01
# 1589     LEWI     Lewis & Clark NHP 2017-04-01
#
#                                                Comments  Year  MonthName  \
# 0             4/17/2021  Memorial opened to the public.  2021      April
# 1     Park closed for 16 days due to government shut...  2013    October
# 2             Sep 16: lost power due to Hurricane Ike.   2008  September
# 3     Park was closed from December 22 - December 31...  2018   December
# 4     May 10-11: 4,300 Boy & Girl Scouts participate...  2008       June
# ...                                                 ...   ...        ...
# 1585  We've only had a couple icy/frosty mornings so...  2017   December
# 1586  It seems like we've been busy and had quite a ...  2017    October
# 1587  June 1-12 were counted as the rest of the scho...  2005       June
# 1588  The biggest factor impacting our visitation th...  2017     August
# 1589  We've been having about 5 people each day comi...  2017      April
#
#       MonthNumber                                             Prompt  \
# 0               4  Comment for April:\n4/17/2021  Memorial opened...
# 1              10  Comment for October:\nPark closed for 16 days ...
# 2               9  Comment for September:\nSep 16: lost power due...
# 3              12  Comment for December:\nPark was closed from De...
# 4               6  Comment for June:\nMay 10-11: 4,300 Boy & Girl...
# ...           ...                                                ...
# 1585           12  Comment for December:\nWe've only had a couple...
# 1586           10  Comment for October:\nIt seems like we've been...
# 1587            6  Comment for June:\nJune 1-12 were counted as t...
# 1588            8  Comment for August:\nThe biggest factor impact...
# 1589            4  Comment for April:\nWe've been having about 5 ...
#
#       WordCount  TokenCount  CharacterCount
# 0             9          17              60
# 1            12          15              72
# 2            11          16              64
# 3            15          19              85
# 4            14          25              82
# ...         ...         ...             ...
# 1585         68          88             367
# 1586         68          89             390
# 1587         75          94             416
# 1588        125         154             680
# 1589        129         160             703
#
# [1590 rows x 11 columns]

# %% [markdown]
# # Estimate GPT Cost

# %%
n = sample.shape[0]
commentTokens = sample['TokenCount'].sum()
print("Total tokens in sample:", commentTokens)
print("Total tokens in sample + prompt:", commentTokens + openai_prompt_tokens*n)
print("Total price:", (commentTokens + openai_prompt_tokens*n) * 0.00000015 + n*150*0.0000015)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Sample 40 comments from the filtered data
# ----> 2 n = sample.shape[0]
#       3 commentTokens = sample['TokenCount'].sum()
#       4 print("Total tokens in sample:", commentTokens)
#
# NameError: name 'sample' is not defined

# %%
print(sample['Comments'][1])
# Out:
# Park closed for 16 days due to government shutdown.

# %% [markdown]
# # Use GPT-3.5-Turbo to Generate Output

# %%
model_id = 'gpt-3.5-turbo'
client = OpenAI(api_key=API_KEY)

# %%
output = []
for i in tqdm.tqdm(range(0)):
    completion = completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  temperature=0.3,
  max_tokens=150,
  messages=[
    {"role": "system", "content": openai_prompt},
    {"role": "user", "content": sample['Prompt'][i]}
  ]
    )
    output.append(completion.choices[0].message.content)
# Out:
# 100%|██████████| 1590/1590 [15:58<00:00,  1.66it/s]

# %% [markdown]
# # Preview Output

# %%
len(output)
for out in output:
    print(out)
    print("-------------------")
# Out:
# April: No Closures.
# -------------------
# October: Park closed for 16 days due to government shutdown.
# -------------------
# September: No Closures.
# -------------------
# December: Park was closed from December 22 - December 31 due to shutdown.
# -------------------
# June: No Closures.
# -------------------
# October: No Closures.
# -------------------
# May: No Closures.
# -------------------
# October: No Closures.
# -------------------
# April: No Closures.
# -------------------
# June: No Closures.
# -------------------
# October: No Closures.
# -------------------
# July: No Closures.
# -------------------
# December: No Closures.
# -------------------
# December: No Closures.
# -------------------
# November: Belle Haven, Daingerfield, Ft. Hunt Park, Ft. Marcy, Gravelly Point, Riverside Park, and Turkey Run were reported as closed due to malfunctioning counters. Crystal City had low visitation due to construction.
# -------------------
# September: No Closures.
# -------------------
# May: No Closures.
# -------------------
# April: U.S. Marines Memorial, Great Falls Park, and Lanes 1-5 at National Airport were reported as closed due to lack of vehicle reports.
# -------------------
# March: No Closures.
# -------------------
# December: No Closures.
# -------------------
# August: Fort Marcy and Turkey Run were reported as not working, but no specific locations were mentioned as closed.
# -------------------
# November: No Closures.
# -------------------
# June: No Closures.
# -------------------
# February: No Closures.
# -------------------
# January: Claude Moore Colonial Farm was closed for the entire month.
# -------------------
# July: Mount Vernon Estate is closed (point of contact is on vacation).
# -------------------
# March: No Closures.
# -------------------
# June: No Closures.
# -------------------
# April: No Closures.
# -------------------
# February: South parking lot closed for the season.
# -------------------
# November: Douglas Center is closed.
# -------------------
# August: Douglas Center is closed.
# -------------------
# October: Douglas Center is closed.
# -------------------
# September: Douglas Center is closed.
# -------------------
# December: Douglas Center is closed.
# -------------------
# July: Douglas Center is closed for construction.
# -------------------
# October: No Closures.
# -------------------
# January: Public Education Prog was closed due to a shutdown.
# -------------------
# May: Douglas Center is closed due to an unsafe walking bridge.
# -------------------
# March: Campground and South Porter lots were closed.
# -------------------
# April: Central is closed due to water running underneath the road.
# -------------------
# June: Douglas Center is closed.
# -------------------
# February: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: Mt Baldy and Porter S are closed, and Douglas Center is closed for HVAC replacement.
# -------------------
# May: No Closures.
# -------------------
# July: Mt Baldy is reported as using an estimate count, with no specific closures mentioned for other locations.
# -------------------
# September: No Closures.
# -------------------
# October: No Closures.
# -------------------
# December: Park closed on December 22 due to shutdown.
# -------------------
# December: No Closures.
# -------------------
# June: No Closures.
# -------------------
# January: No Closures.
# -------------------
# September: No Closures.
# -------------------
# April: No Closures.
# -------------------
# May: Playwrights theater closed for the month.
# -------------------
# February: No Closures.
# -------------------
# August: No Closures.
# -------------------
# March: No Closures.
# -------------------
# July: No Closures.
# -------------------
# January: Park closed part of the time due to lost park keys and safety concerns, resulting in 3 turn aways.
# -------------------
# June: No Closures.
# -------------------
# December: No Closures.
# -------------------
# April: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# November: Closed Thanksgiving Day.
# -------------------
# December: No Closures.
# -------------------
# October: No Closures.
# -------------------
# November: No Closures.
# -------------------
# September: No Closures.
# -------------------
# January: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: Visitor Center closed for holiday on 12/25.
# -------------------
# May: No Closures.
# -------------------
# September: No Closures.
# -------------------
# March: No Closures.
# -------------------
# February: No Closures.
# -------------------
# April: No Closures.
# -------------------
# February: No Closures.
# -------------------
# March: Visitor center closed on Tuesdays and Wednesdays due to winter hours.
# -------------------
# October: No Closures.
# -------------------
# January: Visitor center closed on Tuesdays and Wednesdays for the winter season.
# -------------------
# February: The visitor center was closed for two consecutive days due to inclement weather.
# -------------------
# May: Visitor center was closed for winter season on Tuesdays and Wednesdays until May 28 (Memorial Day weekend), when it resumed seven-day-per-week operations.
# -------------------
# April: The park visitor center was closed on Tuesdays and Wednesdays throughout the month, as well as for one day due to a snowstorm and six days due to flooding on the Mississippi River.
# -------------------
# January: No Closures.
# -------------------
# February: No Closures.
# -------------------
# March: No Closures.
# -------------------
# July: No Closures.
# -------------------
# September: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# October: No Closures.
# -------------------
# June: No Closures.
# -------------------
# July: No Closures.
# -------------------
# May: No Closures.
# -------------------
# February: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# August: The park was closed on August 23 due to an earthquake and on August 27 at 1600 due to a hurricane.
# -------------------
# September: No Closures.
# -------------------
# December: No Closures.
# -------------------
# February: No Closures.
# -------------------
# April: No Closures.
# -------------------
# January: No Closures.
# -------------------
# March: No Closures.
# -------------------
# May: No Closures.
# -------------------
# August: Guy Sandy area is closed.
# -------------------
# May: Rock Creek campground is closed.
# -------------------
# August: Goddard Youth Camp closed.
# -------------------
# May: State Launch Ramp is closed for road paving.
# -------------------
# July: Guy Sandy West location was closed due to the theft of the traffic counter, resulting in no visitation data for the month.
# -------------------
# June: State Launch Ramp was closed due to road construction.
# -------------------
# January: Campgrounds are closed for the winter season, except for Buckhorn Loop D and Rock Creek.
# -------------------
# September: Buckhorn Loops A & B, and Guy Sandy Campgrounds were reported as closed on September 9, 2008.
# -------------------
# November: Buckhorn Loop A/B, Guy Sandy Campgrounds, Cold Springs group sites, and Central Campgrounds are closed.
# -------------------
# April: State Launch Road and various campgrounds at the park were closed.
# -------------------
# March: Campgrounds Central, Guy Sandy, and Buckhorn Loops A & B are closed. State Launch Ramp is closed due to a road project.
# -------------------
# February: Guy Sandy state launch ramp is closed. All campgrounds are closed except for Rock Creek and Buckhorn Loop D.
# -------------------
# October: Buckhorn Loops A & B, Guy Sandy, Cold Springs, and Central campgrounds are closed.
# -------------------
# September: Guy Sandy boat launch and campground are closed for the season, Buckhorn Loops A & B closed on 9/11/12.
# -------------------
# December: Buckhorn Loop A/B, Buckhorn Loop C, Point Upper Loop, Guy Sandy Campground, Cold Springs, Central Campgrounds, and Goddard Youth Camp were reported as closed.
# -------------------
# November: Central, Cold Springs, Guy Sandy, and Buckhorn Loops A, B, & C campgrounds, as well as the Guy Sandy state launch ramp, are closed.
# -------------------
# December: Campgrounds are closed for the winter season, except for Buckhorn Loop D and Rock Creek. Guy Sandy state launch ramp is closed.
# -------------------
# January: Multiple locations including Goddard Youth Camp, State Launch Ramp, Central, Cold Springs, Guy Sandy, the Point, and Buckhorn Loops A, B & C Campgrounds were reported as closed.
# -------------------
# March: Cold Springs, Central, Guy Sandy & Buckhorn Loops A, B, C campgrounds were closed, along with Guy Sandy State Ramp for the first half of the month.
# -------------------
# April: Buckhorn Loop A & B and Guy Sandy campgrounds were closed for the majority of the month, with Buckhorn Loop C opening on 4/27. Cold Springs and Central campgrounds opened on 4/23.
# -------------------
# June: Cedar Blue, Hwy 177, SW Perimeter Road, SE Perimeter Road, and West Hunting Area were reported as closed for varying durations due to broken machines.
# -------------------
# October: Guy Sandy, Buckhorn Loops A&B, Central and Cold Springs Campgrounds were reported as closed.
# -------------------
# February: Campgrounds Guy Sandy, the Point, Buckhorn Loops A, B, & C, Central & Cold Springs, and Goddard Youth Closed State Launch Ramp were reported as closed due to construction.
# -------------------
# October: Guy Sandy Campground, State Boat Launch, Buckhorn Loop A and Loop B campgrounds, Cold Springs, and Central campgrounds are closed. Guy Sandy West traffic counter was stolen.
# -------------------
# October: No Closures.
# -------------------
# February: Gallatin House is closed Mondays through Fridays on a winter schedule.
# -------------------
# November: Gallatin House is closed except for Saturdays and Sundays during the winter season.
# -------------------
# September: No Closures.
# -------------------
# November: Gallatin House was closed for 22 days.
# -------------------
# January: No Closures.
# -------------------
# April: Gallatin House is open weekends only, but the park grounds and trails are open daily during daylight hours.
# -------------------
# March: Gallatin House is closed except for Saturdays and Sundays.
# -------------------
# January: Gallatin House open weekends only.
# -------------------
# November: Gallatin House is open weekends only, while park grounds and trails are open daily from sunrise to sunset.
# -------------------
# December: Gallatin House is open weekends only, but no other closures reported.
# -------------------
# February: Gallatin House is open weekends only, but no other closures were reported.
# -------------------
# October: Gallatin House was reported as open weekends only, but no other closures were mentioned.
# -------------------
# March: Gallatin House was closed for 22 days.
# -------------------
# December: No Closures.
# -------------------
# February: Gallatin House was closed for 19 days.
# -------------------
# April: No Closures.
# -------------------
# May: No Closures.
# -------------------
# June: Gallatin House was closed on Wednesday, June 21 due to an entrance road paving project.
# -------------------
# January: Gallatin House was closed for 21 days due to winter hours of operation and federal holidays.
# -------------------
# September: No Closures.
# -------------------
# March: Gallatin House open weekends only, closed on Saturday March 4 due to power outage.
# -------------------
# September: No Closures.
# -------------------
# July: No Closures.
# -------------------
# December: Gallatin House at Friendship Hill was closed for 23 days due to winter hours.
# -------------------
# October: Gallatin House is closed on weekdays during the winter season, with only Saturdays and Sundays open.
# -------------------
# April: Gallatin House was closed for 3 days at the beginning of the month due to still being on winter hours, but is now open daily with summer hours.
# -------------------
# November: Closed on Thanksgiving.
# -------------------
# January: No Closures.
# -------------------
# January: Memorial was closed on New Years Day.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# March: Memorial visitor center was closed on March 14 due to significant precipitation.
# -------------------
# October: Visitor Center was closed on October 15 due to a statewide power outage caused by a 6.7 earthquake.
# -------------------
# March: Visitor center closed on March 19 due to extreme weather conditions.
# -------------------
# December: Park closed on December 25 for the holiday.
# -------------------
# December: No Closures.
# -------------------
# January: No Closures.
# -------------------
# November: No Closures.
# -------------------
# November: Monument is closed on Thanksgiving day.
# -------------------
# December: Park was closed on Dec. 25 for Christmas Day.
# -------------------
# September: Visitor center closed until October 6.
# -------------------
# October: No Closures.
# -------------------
# March: Casa Grande Ruins National Monument is closed completely due to the COVID-19 outbreak, with no visitation allowed until further notice.
# -------------------
# July: Casa Grande Ruins National Monument Visitor Center was closed on July 15 for the whole day, as well as on July 21 until 12:00 PM and July 22 for the whole day due to an HVAC system failure.
# -------------------
# August: The park was closed to the public through Friday due to downed power lines along the park boundary and entrance road caused by a microburst.
# -------------------
# March: No Closures.
# -------------------
# May: No Closures.
# -------------------
# April: No Closures.
# -------------------
# December: Visitor center closed on Sunday, December 25.
# -------------------
# January: Visitor center closed on New Year's Day.
# -------------------
# November: Visitor Center closed on Thanksgiving Day.
# -------------------
# November: Visitor center closed on Thanksgiving day.
# -------------------
# August: National Cemetery Road was closed for two days in mid-August due to a sealing and striping project.
# -------------------
# October: Main tour road closed on October 6 until 2PM for tree removal.
# -------------------
# September: No Closures.
# -------------------
# July: No Closures.
# -------------------
# February: No Closures.
# -------------------
# March: No Closures.
# -------------------
# November: No Closures.
# -------------------
# April: Main park road was closed at least twice due to fallen trees caused by strong storms.
# -------------------
# October: No Closures.
# -------------------
# June: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: FODO VC is closed for renovation, with visitor services provided at the Stewart County Visitor Center.
# -------------------
# February: Fort Donelson Road and Graves Battery Road experienced temporary closures due to ice and snow, but no specific locations were reported as closed for the entire month.
# -------------------
# June: Fort Donelson Visitor Center is closed with operations temporarily moved to Stewart County Visitor Center due to construction, with no specified end date.
# -------------------
# May: No Closures.
# -------------------
# December: FODO visitor center is closed for reconstruction, with visitor services temporarily relocated to Stewart County Visitor Center. Park interpretation offices are available near the National Cemetery due to the closure of the visitor center.
# -------------------
# December: No Closures.
# -------------------
# June: No Closures.
# -------------------
# March: The park closed early at 2:30 due to high winds and a power outage.
# -------------------
# January: The Park was closed on 1/15 and 1/16 due to high surf.
# -------------------
# October: The park was closed on October 24, 25, 26, 27, 29, and 30 due to high winds or high surf.
# -------------------
# January: No Closures.
# -------------------
# June: No Closures.
# -------------------
# January: No Closures.
# -------------------
# March: No Closures.
# -------------------
# September: No Closures.
# -------------------
# January: No Closures.
# -------------------
# September: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# April: Park was closed due to Covid-19.
# -------------------
# November: No Closures.
# -------------------
# May: No Closures.
# -------------------
# March: Park closed on March 17 due to Covid-19.
# -------------------
# September: No Closures.
# -------------------
# May: No Closures.
# -------------------
# January: No Closures.
# -------------------
# April: No Closures.
# -------------------
# March: No Closures.
# -------------------
# October: No Closures.
# -------------------
# June: No Closures.
# -------------------
# May: Flight 93 National Memorial and the Visitor Center were closed for the entire month, resulting in zero visits to the Visitor Center and no bus visits recorded.
# -------------------
# March: TULE is closed.
# -------------------
# February: TULE is closed.
# -------------------
# April: TULE is closed for the season.
# -------------------
# January: TULE is closed for the season.
# -------------------
# November: TULE is closed.
# -------------------
# May: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# April: Sand and York Islands closed entire period due to "deer reduction" program.
# -------------------
# June: Long Island closed to visitor camping.
# -------------------
# September: No Closures.
# -------------------
# February: No Closures.
# -------------------
# November: No Closures.
# -------------------
# March: No Closures.
# -------------------
# October: No Closures.
# -------------------
# December: No Closures.
# -------------------
# July: Devil's Island campsite is closed. York Island campsites (1-3) were closed July 1-10.
# -------------------
# December: No Closures.
# -------------------
# May: No Closures.
# -------------------
# November: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: Sand Island and Long Island were closed to camping for the majority of the month due to Black Bear activity and Piping Plover monitors, respectively.
# -------------------
# December: No Closures.
# -------------------
# November: The visitor center is closed for the winter.
# -------------------
# June: No Closures.
# -------------------
# April: No Closures.
# -------------------
# October: HQ Visitor Center closed after Oct. 18th due to budget constraints and will remain closed until May 2014. Meyers Rd. was closed during the shutdown.
# -------------------
# June: Manitou Island did not have a volunteer, and the fish camp was closed Tuesday-Friday for maintenance work. Meyers Beach did not have regular coverage until June 17th. LSB had volunteers starting on June 19th.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# July: No Closures.
# -------------------
# October: Offices closed due to COVID.
# -------------------
# May: No Closures.
# -------------------
# December: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: No Closures.
# -------------------
# May: Park closed due to COVID-19.
# -------------------
# September: No Closures.
# -------------------
# June: Trail Center and Visitor Center closed due to COVID. The Canadian side of the Chilkoot Trail is closed due to COVID.
# -------------------
# March: No Closures.
# -------------------
# July: WWII memorial was closed on July 4th for the last half of the day.
# -------------------
# December: No Closures.
# -------------------
# February: No Closures.
# -------------------
# December: Park closed on 12/19-12/21 due to a snow storm and on 12/25.
# -------------------
# December: No Closures.
# -------------------
# January: No Closures.
# -------------------
# January: Memorial was closed most of the day on January 18 for inaugural activities.
# -------------------
# November: No Closures.
# -------------------
# October: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# October: Santa Rosa HWY/399 closed due to storm damage.
# -------------------
# November: No Closures.
# -------------------
# April: No Closures.
# -------------------
# March: Shell road closed until further notice.
# -------------------
# May: No Closures.
# -------------------
# April: No Closures.
# -------------------
# September: Santa Rosa HWY 399 is closed.
# -------------------
# January: No Closures.
# -------------------
# May: No Closures.
# -------------------
# February: No Closures.
# -------------------
# December: No Closures.
# -------------------
# November: Santa Rosa Hwy 399 was closed due to Hurricane Michael damage. PK traffic counter was not working properly.
# -------------------
# July: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# October: Fort Pickens Area was closed from October 9 to October 19, and Hwy 399 remains closed until further notice due to storm damage.
# -------------------
# March: No Closures.
# -------------------
# September: Park closed for 9/4 and 9/5 for TS Gordon.
# -------------------
# December: The park was closed to visitors from December 22 to January 27 due to a government shutdown. All areas except for 399 remained closed to visitors.
# -------------------
# March: No Closures.
# -------------------
# July: No Closures.
# -------------------
# January: Visitor Center closed for 1 day and delayed opening for two days due to ice and snow.
# -------------------
# December: No Closures.
# -------------------
# May: No Closures.
# -------------------
# May: No Closures.
# -------------------
# March: Visitor Center was closed on March 2 due to snow and ice.
# -------------------
# February: No Closures.
# -------------------
# October: Kings Mountain celebration and Education Days were impacted by a government shutdown.
# -------------------
# August: Horse trail was only open for about 2.5 weeks, part of hiking trails in adjoining State Park still closed.
# -------------------
# February: State park closure of campground/picnic area due to bridge construction.
# -------------------
# July: Horse Trails are closed due to significant tornado damage, discussions ongoing with adjoining state park for trail clearance.
# -------------------
# July: No Closures.
# -------------------
# June: The horse trail has been closed since June 16 due to extreme damage from a tornado system, affecting both the park and the adjoining state park.
# -------------------
# April: No Closures.
# -------------------
# September: Sea Plane and Ferry locations are closed.
# -------------------
# December: No Closures.
# -------------------
# December: No Closures.
# -------------------
# November: Ferry Boat and sea plane not reporting.
# -------------------
# July: No Closures.
# -------------------
# October: No Closures.
# -------------------
# May: No Closures.
# -------------------
# March: No Closures.
# -------------------
# April: No Closures.
# -------------------
# October: No Closures.
# -------------------
# February: No Closures.
# -------------------
# February: Sea Plane and Ferry Boat locations were reported as closed, with visitation numbers estimated using recent years.
# -------------------
# March: No Closures.
# -------------------
# November: Ferry was closed for maintenance for 7 days.
# -------------------
# January: No Closures.
# -------------------
# June: Ferry company and seaplane services were not operational, with the ferry service estimated using recent data.
# -------------------
# June: No Closures.
# -------------------
# November: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: The park was closed on December 25, 2017.
# -------------------
# March: No Closures.
# -------------------
# November: Site closed on 11/27/2014 for Thanksgiving.
# -------------------
# February: No Closures.
# -------------------
# February: Site closed on 2/12-13/2014 due to winter storm weather.
# -------------------
# April: No Closures.
# -------------------
# June: No Closures.
# -------------------
# January: Site closed from 1/28 - 1/30/14 due to an ice storm.
# -------------------
# September: No Closures.
# -------------------
# February: No Closures.
# -------------------
# November: Museum entrance changed due to painting project, closed on November 23 for Thanksgiving.
# -------------------
# December: The park was closed at 3:00 on December 24th and closed for the Christmas holiday on December 25th.
# -------------------
# April: No Closures.
# -------------------
# October: Museum/Visitor exterior painting affected visitor access; Annual Naturalization Ceremony on 10/20/2017.
# -------------------
# July: No Closures.
# -------------------
# March: No Closures.
# -------------------
# September: The park was closed to the public from September 8-14th due to Hurricane Irma, and the Annual Naturalization Ceremony on September 16 was cancelled.
# -------------------
# August: No Closures.
# -------------------
# January: Charleston was closed due to inclement weather, and the museum at Boone Hall was closed early on the 17th for an event.
# -------------------
# June: House closed for events on 6/9 and 6/10.
# -------------------
# April: The house was closed for ranger tours on 4/9, 4/16, and 4/23, and also for the "Blessing of the Flee" event on 4/20.
# -------------------
# May: The house was closed on multiple occasions for guided tours, a break, and a special event, with closures also occurring during the NOLA Jazz Program.
# -------------------
# March: The house was closed for a ranger tour on March 5, a self-guided group of over 20 visited on March 9, a cub scout group of 19 visited on March 10, a self-guided educational group of 20 students visited on March 17, and a cub scout group of 37 visited on March 19.
# -------------------
# March: No Closures.
# -------------------
# April: No Closures.
# -------------------
# June: Highway 24, the primary route to the Florissant area, was closed from Sunday 6/24/12 to 7/1/12.
# -------------------
# October: No Closures.
# -------------------
# September: No Closures.
# -------------------
# January: The park was closed for two days due to a holiday and severe winter weather.
# -------------------
# November: Closed on Nov. 22nd for Thanksgiving.
# -------------------
# April: The park was closed for 1 1/2 days due to a major snow event.
# -------------------
# December: The park was closed on December 24th, 25th, and closed early at 14:30 on December 31st.
# -------------------
# January: No Closures.
# -------------------
# October: Some areas of the park may be closed during the weekdays as the park has transitioned to a winter schedule with limited staff, but efforts are made to accommodate drop-by visitors.
# -------------------
# January: No Closures.
# -------------------
# December: Garfield home remains closed for HVAC system installation, impacting visitation numbers.
# -------------------
# February: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: Miller Field and Great Kills data not available.
# -------------------
# May: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# October: No Closures.
# -------------------
# March: No Closures.
# -------------------
# March: Ft. Wadsworth ped/bike path counter was inaccessible due to construction.
# -------------------
# November: Ft. Wadsworth and Miller Field visitation numbers are pending, with no mention of closures.
# -------------------
# January: Campgrounds in all Gateway units are closed for the season. The Sandy Hook Lighthouse is still closed due to construction.
# -------------------
# August: No Closures.
# -------------------
# May: Ft. Wadsworth bike path remains closed to the public due to construction, resulting in lower visitation numbers compared to last year.
# -------------------
# August: Great Kills data not submitted due to a family emergency; missing data from two areas in the park pending response from responsible parties.
# -------------------
# May: No Closures.
# -------------------
# September: Ft. Wadsworth in the North shore district is closed for the season, with zero stats reported due to the end of seasonal staff and programs. Great Kills and Fort Wadsworth traffic counts are estimated.
# -------------------
# April: No Closures.
# -------------------
# November: No Closures.
# -------------------
# February: No Closures.
# -------------------
# September: Great Kills location was closed for most of the month due to a fire.
# -------------------
# September: No Closures.
# -------------------
# October: Great Kills and Fort Wadsworth locations are reported as closed due to broken counters, with no specific reopening date mentioned. Miller Field and Ecology Village are awaiting visitor numbers.
# -------------------
# December: No Closures.
# -------------------
# January: Bldg.135 at Floyd Bennett Field and Bldg. 1 at Fort Tilden are reported as closed for the month.
# -------------------
# April: Sandy Hook lighthouse is still under renovations, camping at FOWA is not open yet due to construction, and Camp Gateway at Floyd Bennett field will not open until May.
# -------------------
# December: No Closures.
# -------------------
# February: No Closures.
# -------------------
# December: Nemo location may be affected by a malfunctioning counter, but no closures are explicitly mentioned.
# -------------------
# September: No Closures.
# -------------------
# June: No Closures.
# -------------------
# September: No Closures.
# -------------------
# June: No Closures.
# -------------------
# November: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# May: Nemo location is experiencing a malfunction with the counter, but no closures are mentioned.
# -------------------
# July: No Closures.
# -------------------
# April: No Closures.
# -------------------
# January: Nemo traffic counter malfunction, low water levels affecting whitewater paddlers.
# -------------------
# October: No Closures.
# -------------------
# January: No Closures.
# -------------------
# December: Obed visitor center and Rock Creek Campground were closed for the entire month due to the government shutdown.
# -------------------
# February: Visitor Center was closed for 5 days and experienced delays on 3 other days.
# -------------------
# March: Catoosa Wildlife Management Area was closed, resulting in zero visitation at Potter's Ford, Devil's Breakfast Table, etc.
# -------------------
# December: No Closures.
# -------------------
# August: No Closures.
# -------------------
# January: No Closures.
# -------------------
# August: Park closed on August 20 & 21 due to Tropical Storm Hilary.
# -------------------
# April: No Closures.
# -------------------
# November: ROWI Visitors Center was closed for Thanksgiving Day.
# -------------------
# March: ROWI VC was closed on March 2 due to snow.
# -------------------
# May: No Closures.
# -------------------
# September: No Closures.
# -------------------
# January: ROWI VC was closed from 1/1 until 1/26 due to the Government shutdown.
# -------------------
# February: No Closures.
# -------------------
# October: No Closures.
# -------------------
# December: The park closed early on December 24th, remained closed on December 25th, and closed early on December 31st.
# -------------------
# December: The park was closed all day on December 25th and closed 2 hours early on December 24th and 31st.
# -------------------
# April: ROWI Visitor Center was closed for just over an hour on April 20th due to a gas leak.
# -------------------
# January: The park was closed on January 1 for New Year's Day and on January 23rd and 24th due to heavy snow from the Blizzard of 2005.
# -------------------
# May: No Closures.
# -------------------
# September: No Closures.
# -------------------
# June: No Closures.
# -------------------
# June: No Closures.
# -------------------
# February: Visitor Center closed on Feb 1, 2, 3 due to severe weather and natural gas leak.
# -------------------
# January: Visitor Center was closed on multiple days due to severe winter storms, a natural gas leak, and early closure for winter weather.
# -------------------
# August: The park was closed on August 28 due to Hurricane Irene, but reopened on August 29 despite power outages in the surrounding areas.
# -------------------
# February: No Closures.
# -------------------
# July: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# May: No Closures.
# -------------------
# February: No Closures.
# -------------------
# October: 2 Rivers location is closed due to construction.
# -------------------
# January: No Closures.
# -------------------
# September: No Closures.
# -------------------
# September: No Closures.
# -------------------
# September: No Closures.
# -------------------
# June: No Closures.
# -------------------
# December: No Closures.
# -------------------
# April: Trails are closed due to flooding, with water still present on some trails and sections missing on others.
# -------------------
# December: Visitor center is still undergoing repair work, but no specific locations are reported as closed.
# -------------------
# January: No Closures.
# -------------------
# December: Park closed 3 days due to weather conditions.
# -------------------
# March: Visitor center was closed for two days due to snow and weather conditions. Park flooded with river banks eroding.
# -------------------
# November: Visitor center theater and museum closed for repair work and replacement of carpet.
# -------------------
# January: Visitor center closed 1 entire day and closed 2 hours early on another day due to bad weather.
# -------------------
# June: No Closures.
# -------------------
# May: No Closures.
# -------------------
# October: No Closures.
# -------------------
# July: No Closures.
# -------------------
# August: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# November: Namekagon and Headquarters Visitor Centers are closed for the Winter.
# -------------------
# December: Namekagon and Headquarters Visitor Centers are closed for the Winter.
# -------------------
# March: Marshland Visitor Center is closed, and the other two visitor centers are closed for the winter.
# -------------------
# April: Marshland Visitor Center is closed, while the other two visitor centers are closed for the winter.
# -------------------
# February: Marshland Visitor Center is closed, and the other two visitor centers are closed for the winter.
# -------------------
# January: Marshland Visitor Center is closed, and the other two visitor centers are closed for the winter.
# -------------------
# April: No Closures.
# -------------------
# October: Osceola Day Use Area, Osceola Landing/Launch, Earl Landing, Stinnett Landing, Hwy 70 Landing, Riverside Landing, and Osceola Picnic Area were reported as closed by 10/16 or 10/26.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# June: No Closures.
# -------------------
# May: Earl Landing was reported as closed at the end of the month from 5/28-31 due to a malfunctioning counter.
# -------------------
# February: No Closures.
# -------------------
# May: No Closures.
# -------------------
# March: No Closures.
# -------------------
# October: WRVC is closed for the season.
# -------------------
# September: White River Valley Campground is closed due to the Interior Entrance Traffic Counter not working.
# -------------------
# June: WRVC closed due to Covid-19.
# -------------------
# August: WRVC closed due to Covid-19.
# -------------------
# February: No Closures.
# -------------------
# March: WRVC Closed for the season.
# -------------------
# October: White River Visitor Center was closed on October 4th, and Cedar Cabins were closed on the 15th.
# -------------------
# June: No Closures.
# -------------------
# December: Cedar Pass Lodge and WRVC were closed, Interior Traffic Counter was not working, and NE and Pinn did not download.
# -------------------
# April: WRVC is closed for the season, but no other closures were reported.
# -------------------
# July: WRVC is closed due to Covid-19, no other closures mentioned.
# -------------------
# April: WRVC was reported as closed.
# -------------------
# November: WRVC & Cedar Pass Lodge were reported as closed for the season.
# -------------------
# August: No Closures.
# -------------------
# January: Interior Entrance is closed due to a non-functional traffic counter.
# -------------------
# June: Morrow Point boat tour was closed until June 25.
# -------------------
# May: Morrow Point boat tours were cancelled all month due to high water discharges from Blue Mesa Dam.
# -------------------
# March: Some campgrounds are still closed due to ongoing issues, and there are problems with traffic counters. Ground conditions are preventing the fixing of wiring issues.
# -------------------
# October: East Elk Creek CG and Red Creek Group CG were reported as closed due to maintenance issues.
# -------------------
# November: Red Creek is closed for the winter season.
# -------------------
# May: East Elk campground is still closed due to an Eagle nest.
# -------------------
# April: Iola and Pioneer Point reported closures due to dead batteries, while Dead Battery Middle Bridge and Lake Fork experienced high count problems.
# -------------------
# June: East Elk Group Campsite is closed due to nesting bald eagles, impacting group counts.
# -------------------
# September: No Closures.
# -------------------
# November: Dry Creek and East Elk Creek Campgrounds are closed, along with Red Creek Group Campground. Additionally, boat ramps are closed due to low water levels.
# -------------------
# January: Iola and Soap Creek were closed due to a dead battery and possible broken middle bridge line. No other closures were reported.
# -------------------
# August: Dead Battery, Cooper Ranch, Bay of Chickens, and Old Stevens were closed. Hwy 50 was open in August due to problems on I70, resulting in less traffic at Pioneer Pt and Hwy 92.
# -------------------
# February: No Closures.
# -------------------
# July: No Closures.
# -------------------
# August: No Closures.
# -------------------
# December: No Closures.
# -------------------
# May: No Closures.
# -------------------
# June: No Closures.
# -------------------
# January: No Closures.
# -------------------
# March: No Closures.
# -------------------
# February: No Closures.
# -------------------
# April: No Closures.
# -------------------
# September: No Closures.
# -------------------
# November: No Closures.
# -------------------
# November: No Closures.
# -------------------
# January: No Closures.
# -------------------
# October: Some data collection was impacted by a government shutdown from Oct 1-17, resulting in incomplete vehicle numbers and cabin overnight stay values.
# -------------------
# April: No Closures.
# -------------------
# June: No Closures.
# -------------------
# May: No Closures.
# -------------------
# March: No Closures.
# -------------------
# May: Kipahulu car-counter was inoperable due to construction, with counts carried over from the previous month. Horseback and helicopter counts were pending updates.
# -------------------
# June: Kipahulu car-counter was closed due to construction, but no other closures were reported.
# -------------------
# October: No Closures.
# -------------------
# July: Kipahulu car-counter is closed due to construction, but no other specific locations are reported as closed.
# -------------------
# September: No Closures.
# -------------------
# March: Kipahulu campground was closed for the month.
# -------------------
# December: No Closures.
# -------------------
# November: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: Kipahulu car-counter remains inoperable, but no specific locations are reported as closed.
# -------------------
# April: Kipahulu car counter was inoperable due to construction, with counts carried over from the previous month. No other closures were reported.
# -------------------
# October: Kipahulu traffic counter is inoperable, and helicopter and horse counts are pending updates. No closures mentioned.
# -------------------
# August: Kipahulu traffic counter was inoperable, so figures were based on an average from when the traffic counter was last working (Oct 2010 to June 2011). No closures mentioned.
# -------------------
# January: Kipahulu car-counter is inoperable due to construction, campground count is pending, and helicopter & horse counts will be updated later.
# -------------------
# February: Kipahulu car counter is inoperable due to construction, campground counts are pending, and helicopter and horse counts are pending. No closures mentioned.
# -------------------
# February: No Closures.
# -------------------
# July: No Closures.
# -------------------
# December: Visitor Center closed for a significant portion of the month.
# -------------------
# December: Visitor Center is closed.
# -------------------
# June: No Closures.
# -------------------
# May: No Closures.
# -------------------
# November: Weir Studio, Young Studios, and Weir House Tours are closed to the general public, open only for special education groups.
# -------------------
# July: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# March: USS Cassin Young in dry dock - no on-board visits.
# -------------------
# March: No Closures.
# -------------------
# February: Bunker Hill Monument was closed due to ice on steps; Cassin Young was in dry dock; the park was closed for 1.5 days due to snow.
# -------------------
# December: USS Cassin Young and Shipyard Galley are closed for the season. Shutdown started on December 22.
# -------------------
# April: Bunker Hill Monument is closed due to maintenance issues.
# -------------------
# May: Bunker Hill Monument is closed due to high COVID rating in Boston area and maintenance issues.
# -------------------
# November: USS Cassin Young and Seasonal Shipyard Galley are closed for the winter. Old North Church now charges admission.
# -------------------
# January: Bunker Hill Monument was closed; USS Cassin Young was in dry dock with no visits aboard.
# -------------------
# June: BH Monument and Ship Galley are reported as closed due to renovation issues and unlikely to reopen. Old South Meeting House and Old State House have combined operations under Revolutionary Spaces.
# -------------------
# April: Great Hall and Faneuil Hall VC were reported as closed for renovations.
# -------------------
# January: Great Hall, Faneuil Hall VC, USS Cassin Young, and Shipyard Galley were closed for renovations and the season, with the park closed for a total of 5 days due to snow and shutdowns.
# -------------------
# January: BH Monument and Old North were closed due to covid concerns, USS Cassin Young was closed seasonally, and some sites had reduced hours due to omicron concerns.
# -------------------
# February: Old State House and Old South Meeting House (Revolutionary Spaces) were open, but USS Cassin Young had limited opening on two days due to unseasonal warm weather. Some sites had reduced hours for two snow days.
# -------------------
# July: Bunker Hill Monument reopened on a limited basis after a closure since March 2020 due to staffing and logistics issues.
# -------------------
# May: Great Hall remains closed for renovation, while Faneuil Hall VC reopened on May 14. Temporary VC at 15 State was closed on May 19.
# -------------------
# February: USS Cassin Young, Shipyard Galley, Great Hall, and Faneuil Hall VC were reported as closed, with a temporary VC at 15 State Street included as a "Special Event".
# -------------------
# March: Great Hall and Faneuil Hall VC are closed for renovations, USS Cassin Young and Shipyard Galley are closed seasonally.
# -------------------
# February: No Closures.
# -------------------
# January: No Closures.
# -------------------
# April: The park was closed on Saturday, April 15, 2023, due to staff shortage.
# -------------------
# December: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# November: The park is closed on Mondays, Tuesdays, and Wednesdays until the week of February 19th, 2024.
# -------------------
# July: CMA was reported as closed for the entire month.
# -------------------
# July: No Closures.
# -------------------
# December: No Closures.
# -------------------
# October: No Closures.
# -------------------
# May: No Closures.
# -------------------
# June: No Closures.
# -------------------
# September: No Closures.
# -------------------
# March: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# April: No Closures.
# -------------------
# November: No Closures.
# -------------------
# May: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# September: No Closures.
# -------------------
# February: No Closures.
# -------------------
# November: No Closures.
# -------------------
# December: Island and Mainland Visitor Center closed, no visitation.
# -------------------
# October: Voyageur location closed one week ahead of schedule.
# -------------------
# July: Wenonah is closed due to low lake levels, and Voyageur is only running day trips to West District on Fridays.
# -------------------
# June: Wenonah is closed due to low lake levels.
# -------------------
# January: Park and visitor centers closed for the winter, leading to no visitation and cancellation of the winter study.
# -------------------
# February: Park and visitor centers closed for the winter, resulting in no visitation.
# -------------------
# March: Park and visitor centers closed for the winter.
# -------------------
# August: Wenonah and concession seaplane services were closed for the month, with Voyageur operating limited day trips.
# -------------------
# April: Houghton Visitor Center was closed until April 19th for the season.
# -------------------
# January: Houghton VC was only open for 2 days in January 2019.
# -------------------
# June: No Closures.
# -------------------
# September: Kettle Falls hotel closed for building maintenance.
# -------------------
# November: Rainy Lake Visitor Center was closed from October 21 through November 29, 2019.
# -------------------
# January: No Closures.
# -------------------
# October: Rainy Lake Visitor Center was closed from October 21, 2019 through November 29, 2019.
# -------------------
# July: ARVC was closed three days per week due to staffing issues.
# -------------------
# August: Ash River Visitor Center was closed Mondays through Wednesdays due to staffing issues.
# -------------------
# March: No Closures.
# -------------------
# February: No Closures.
# -------------------
# April: Headquarters Building had no desk staff present from April 12 to May 28, 2019, with visitation statistics estimated based on the last 3 years.
# -------------------
# May: HQ desk was closed from April 12, 2019 through May 27, 2019 due to staff changeover.
# -------------------
# January: No Closures.
# -------------------
# December: Rainy Lake Visitor Center was open only on weekends, and Rainy Lake Ice Road and Kabetogama Ice Road remained closed throughout the month.
# -------------------
# January: Ice roads did not open, two snowmobile trails remained closed all month, and ski and snowmobile trails that opened could not be groomed due to insufficient snow. Rainy Lake Visitor Center and Kabetogama Lake Visitor Center were open on weekends.
# -------------------
# March: Sphunge Island sledding hill was closed for the entire season, and lake-based snowmobile trails were closed much earlier than usual due to warm temperatures and dangerous ice conditions.
# -------------------
# May: No Closures.
# -------------------
# September: The memorial was closed for the entire month due to rehabilitation.
# -------------------
# May: Some park locations were closed due to COVID-19 delaying the park opening until mid-June.
# -------------------
# May: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# ...
# -------------------
# August: Loop Road and backcountry closed due to flood damage. Slaughter Canyon Cave remains closed. Wild cave trips remain suspended.
# -------------------
# January: Slaughter Canyon Cave and the Loop Road are closed due to flood damage.
# -------------------
# May: No Closures.
# -------------------
# January: No Closures.
# -------------------
# December: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# February: Salem Church and Ellwood are closed.
# -------------------
# April: Salem Church was reported as closed.
# -------------------
# January: Park was shut down virtually all month due to a lapse in appropriations.
# -------------------
# December: No Closures.
# -------------------
# March: Salem Church closed, Jackson Shrine open weekends until March 17, then 7 days a week.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# November: No Closures.
# -------------------
# October: No Closures.
# -------------------
# September: No Closures.
# -------------------
# May: No Closures.
# -------------------
# January: Ellwood and Salem Church were closed. Sunken Road and Jackson Wounding walking tours were severely affected by inclement weather. Park was closed for four days due to a snowstorm.
# -------------------
# July: Chancellorsville Visitor Center had reduced visits for 2 days due to parking lot paving, and the Wilderness Exhibit Shelter was closed for 4 days for the same reason.
# -------------------
# February: No Closures.
# -------------------
# December: Building closed on 25 December.
# -------------------
# December: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: No Closures.
# -------------------
# January: No Closures.
# -------------------
# October: No Closures.
# -------------------
# November: No Closures.
# -------------------
# February: Site closed on 18th for Washington's Birthday, and on 12th for Homeland Security Conference. Long Range Interpretive Planning Meeting held on 28th.
# -------------------
# July: Federal Hall was closed for a significant portion of the month due to maintenance issues with the HVAC system.
# -------------------
# November: No Closures.
# -------------------
# March: No Closures.
# -------------------
# February: Park closed and had delayed openings a few days due to inclement weather.
# -------------------
# June: No Closures.
# -------------------
# January: The park was closed on New Year's Day and MLK, Jr. Day, and experienced a 3-day closure due to inclement weather conditions.
# -------------------
# October: No Closures.
# -------------------
# February: No Closures.
# -------------------
# November: No Closures.
# -------------------
# November: Exhibition buildings are closed from November through late May, but the grounds and Visitor Center remain open with limited hours.
# -------------------
# December: Park closed due to partial gov't shutdown from 12/22/2018 - 1/27/2019.
# -------------------
# September: No Closures.
# -------------------
# April: No Closures.
# -------------------
# August: No Closures.
# -------------------
# July: No Closures.
# -------------------
# January: No Closures.
# -------------------
# February: Visitor Center closed on the 23rd for winter weather.
# -------------------
# October: No Closures.
# -------------------
# June: Monument closed between 6/13 and 6/21 due to Pipeline Fire.
# -------------------
# April: Crack in Rock overnight hike was closed on the 8-9th and 15-16th.
# -------------------
# December: Visitor Center was closed on 12/11 and Christmas Day.
# -------------------
# September: No Closures.
# -------------------
# April: The monument was closed from April 20th to April 29th due to the Tunnel Fire.
# -------------------
# May: Road construction is ongoing, causing all 21 miles of road within the park to be dirt and resulting in slow traffic; however, no specific locations are reported as closed.
# -------------------
# September: Moore House closed for hurricane watch.
# -------------------
# April: No Closures.
# -------------------
# January: No Closures.
# -------------------
# October: Minimal closures due to Hurricane Irene, resulting in low visitation.
# -------------------
# August: Road and visitor center closures occurred due to Hurricane Irene.
# -------------------
# February: No Closures.
# -------------------
# November: No Closures.
# -------------------
# December: No Closures.
# -------------------
# March: No Closures.
# -------------------
# May: The Moore House and Nelson House are reported as closed due to a lack of volunteers. No other closures are mentioned.
# -------------------
# April: The Moore House and Nelson House are closed due to the park's volunteer program being on hiatus.
# -------------------
# November: The Moore House and Nelson House are closed due to a lack of volunteers.
# -------------------
# June: Moore House and Nelson House are closed due to a lack of volunteers.
# -------------------
# September: Moore House and Nelson House are closed due to a lack of volunteers.
# -------------------
# July: The Moore House and Nelson House are closed due to a lack of volunteers.
# -------------------
# August: The Moore House and Nelson House are closed due to a lack of volunteers.
# -------------------
# March: Moore House and Nelson House are closed due to the volunteer program hiatus.
# -------------------
# October: Moore House and Nelson House remain closed due to a lack of volunteers, except for Nelson House opening on Yorktown Day. No other closures reported.
# -------------------
# February: Jamestown Visitor Center was closed in 2021 due to the COVID-19 pandemic, while the Moore House and Nelson House remain closed due to the park's volunteer program hiatus.
# -------------------
# January: Jamestown Island Visitor Center fee collection operation was closed for two weeks due to a COVID-19 outbreak. Moore House and Nelson House are closed due to the park's volunteer program being on hiatus.
# -------------------
# April: No Closures.
# -------------------
# May: No Closures.
# -------------------
# June: No Closures.
# -------------------
# July: No Closures.
# -------------------
# November: No Closures.
# -------------------
# December: No Closures.
# -------------------
# May: No Closures.
# -------------------
# June: No Closures.
# -------------------
# December: No Closures.
# -------------------
# September: No Closures.
# -------------------
# August: No Closures.
# -------------------
# January: No Closures.
# -------------------
# November: No Closures.
# -------------------
# May: No Closures.
# -------------------
# April: No Closures.
# -------------------
# January: No closures.
# -------------------
# December: No Closures.
# -------------------
# March: No Closures.
# -------------------
# October: No Closures.
# -------------------
# August: No Closures.
# -------------------
# February: The park was shut down due to snow storms, with a few half-day closures. The counter cable was torn off by a snow plow, but repairs are underway.
# -------------------
# June: No Closures.
# -------------------
# September: No Closures.
# -------------------
# January: No Closures.
# -------------------
# August: No Closures.
# -------------------
# May: No Closures.
# -------------------
# April: No Closures.
# -------------------
# December: Trunk Bay and the Visitor Center were reported as closed for the month.
# -------------------
# March: No Closures.
# -------------------
# July: No Closures.
# -------------------
# July: No Closures.
# -------------------
# September: Caneel Bay Resort and Cinnamon Bay Campground were closed for the month.
# -------------------
# January: No Closures.
# -------------------
# April: No Closures.
# -------------------
# June: No Closures.
# -------------------
# August: Annaberg Sugarmill was closed for the month.
# -------------------
# January: No Closures.
# -------------------
# February: British Virgin Islands shut down, leading to high boat counts at North and South shores.
# -------------------
# December: No Closures.
# -------------------
# March: Trunk Bay is not collecting fees, impacting tour counts, and Tortola Ferries counts are low due to Customs not fully operating on St. John.
# -------------------
# January: No Closures.
# -------------------
# January: No Closures.
# -------------------
# March: No Closures.
# -------------------
# December: No Closures.
# -------------------
# January: No Closures.
# -------------------
# October: No Closures.
# -------------------
# February: Shays' Resistance and Hartford Flower Show were reported as closed.
# -------------------
# April: Infrastructure upgrade and COVID-19 closures mentioned.
# -------------------
# December: No Closures.
# -------------------
# March: Museum closed due to construction/infrastructure upgrade.
# -------------------
# February: The park was closed for the entire month due to infrastructure upgrades.
# -------------------
# November: No Closures.
# -------------------
# March: No Closures.
# -------------------
# July: Armory Day and Big Band locations were reported as closed.
# -------------------
# February: No Closures.
# -------------------
# August: No Closures.
# -------------------
# June: Museum closed due to infrastructure upgrades and COVID-19.
# -------------------
# July: Museum closed due to COVID.
# -------------------
# May: No Closures.
# -------------------
# October: Museum closed due to COVID-19.
# -------------------
# July: No Closures.
# -------------------
# June: Hartford Farmer's Market, Hartford Blooms, and writing camp were reported as closed.
# -------------------
# October: No Closures.
# -------------------
# September: No Closures.
# -------------------
# April: No Closures.
# -------------------
# June: Armory Day, Community Music School, and Coltsville Walking tours were closed.
# -------------------
# April: Birchland Park was closed for a blank firing demonstration for schools during school vacation week.
# -------------------
# August: Museum closed due to COVID.
# -------------------
# August: No Closures.
# -------------------
# September: Museum closed due to COVID.
# -------------------
# November: No Closures.
# -------------------
# September: Coltsville Walking tours, Big E, blank firing demonstration, and Naturalization Ceremony were reported as closed.
# -------------------
# May: Museum closed for infrastructure upgrades and COVID-19 precautions.
# -------------------
# May: Birchland Park Middle School and Phoenix Charter School were closed this month.
# -------------------
# November: Museum closed due to COVID-19.
# -------------------
# February: Park closed due to COVID-19.
# -------------------
# December: Site closed for Covid safety.
# -------------------
# January: Site closed until 2011.
# -------------------
# July: Inside areas closed due to the Covid-19 pandemic.
# -------------------
# January: Inside areas were closed due to COVID-19.
# -------------------
# May: Inside locations closed due to the 2019 Novel Coronavirus.
# -------------------
# September: Site closed due to COVID-19.
# -------------------
# April: Specific location closed due to COVID-19.
# -------------------
# March: No Closures.
# -------------------
# October: Hamilton Grange N.M. is closed for indoor access, but the grounds are open.
# -------------------
# May: Park is closed for 1.5 years to relocate 1 block away.
# -------------------
# November: Hamilton Grange N.M. is closed for indoor access, but the grounds are open.
# -------------------
# June: Hamilton Grange National Memorial is closed.
# -------------------
# August: No Closures.
# -------------------
# September: No Closures.
# -------------------
# July: LBJ location closed.
# -------------------
# June: LBJ counter closed.
# -------------------
# November: No Closures.
# -------------------
# July: Camp 44 in the backcountry is closed.
# -------------------
# October: No Closures.
# -------------------
# August: Camp 44 in the backcountry is closed.
# -------------------
# May: No Closures.
# -------------------
# September: No Closures.
# -------------------
# March: No Closures.
# -------------------
# April: No Closures.
# -------------------
# January: Lost Man Creek and Wolf Creek Environmental camp were reported as closed.
# -------------------
# June: 44 Camp [backcountry] closed.
# -------------------
# May: Backcountry Camp is closed due to a bridge failure since February, and overnights are not running at the Environmental School.
# -------------------
# March: Lost Man Creek is closed due to bridge repair. Redwood Creek Horse Trail data is unavailable.
# -------------------
# April: Davison Road was mentioned for inspection, but no closures were reported. Lost Man Creek was reopened on 4/26/22.
# -------------------
# February: No Closures.
# -------------------
# January: Enders, Klamath, and Lagoon Creek were reported as closed due to traffic counters being down, with monthly averages used instead.
# -------------------
# July: Coastal Rd, CBEC, and Hostel are closed to the public.
# -------------------
# May: No Closures.
# -------------------
# December: Davison may have been underwater for some portion of the period.
# -------------------
# June: No Closures.
# -------------------
# February: No Closures.
# -------------------
# February: Lost Man Creek, Environmental camps for overnight stays, and Crescent City Information Center are closed. Redwood Creek backcountry remains open.
# -------------------
# April: No Closures.
# -------------------
# January: CBEC, Coastal Road, hostel, and Hiouchi are closed to the public.
# -------------------
# March: No Closures.
# -------------------
# December: Davison Rd, CBEC, Coastal Road, Redwood Hostel, and Crescent City Information Center were closed due to various reasons, while Hiouchi VC remained open. LBJ counter was temporarily closed for repairs.
# -------------------
# February: No Closures.
# -------------------
# March: No Closures.
# -------------------
# January: No Closures.
# -------------------
# March: No Closures.
# -------------------
# December: No Closures.
# -------------------
# November: No Closures.
# -------------------
# January: No Closures.
# -------------------
# April: No Closures.
# -------------------
# February: No Closures.
# -------------------
# January: No Closures.
# -------------------
# July: No Closures.
# -------------------
# September: No Closures.
# -------------------
# September: No Closures.
# -------------------
# April: Netul Landing was not accessible due to a broken counter, but no other closures were reported.
# -------------------
# April: No Closures.
# -------------------
# August: No Closures.
# -------------------
# August: No Closures.
# -------------------
# March: No Closures.
# -------------------
# March: No Closures.
# -------------------
# May: No Closures.
# -------------------
# October: Fort replica closed due to fire on October 3.
# -------------------
# January: No Closures.
# -------------------
# November: The park was closed on November 12 due to a wind storm, but no specific locations were reported as closed for the entire month.
# -------------------
# February: No Closures.
# -------------------
# October: Netul Landing was closed for the first 10 days due to a road construction project.
# -------------------
# February: No Closures.
# -------------------
# May: No Closures.
# -------------------
# December: The park was closed for 9 1/2 days due to a severe storm, with two trails still closed because of dangerous down trees.
# -------------------
# June: No Closures.
# -------------------
# November: No Closures.
# -------------------
# January: No Closures.
# -------------------
# September: The road between Fort Clatsop and Netul Landing is closed due to a construction project, impacting access to the Netul Landing site.
# -------------------
# November: No Closures.
# -------------------
# July: Netul Landing counter is still broken, but no specific locations are reported as closed.
# -------------------
# July: No Closures.
# -------------------
# December: No Closures.
# -------------------
# February: No Closures.
# -------------------
# June: Netul Landing counter broken, visitor center parking lots closed on July 1 with visitors entering through Netul Landing.
# -------------------
# December: No Closures.
# -------------------
# October: No Closures.
# -------------------
# June: No Closures.
# -------------------
# August: No Closures.
# -------------------
# April: No Closures.
# -------------------

# %% [markdown]
# # Save Output

# %%
output_df = sample.copy()
output_df['Output'] = output
display(output_df)
output_df.to_csv('TrainData/output.csv', index=False)
# Out:
#      UnitCode              ParkName       Date  \
# 0        WWIM  World War I Memorial 2021-04-01
# 1        LIBO  Lincoln Boyhood NMEM 2013-10-01
# 2        LIBO  Lincoln Boyhood NMEM 2008-09-01
# 3        LIBO  Lincoln Boyhood NMEM 2018-12-01
# 4        LIBO  Lincoln Boyhood NMEM 2008-06-01
# ...       ...                   ...        ...
# 1585     LEWI     Lewis & Clark NHP 2017-12-01
# 1586     LEWI     Lewis & Clark NHP 2017-10-01
# 1587     LEWI     Lewis & Clark NHP 2005-06-01
# 1588     LEWI     Lewis & Clark NHP 2017-08-01
# 1589     LEWI     Lewis & Clark NHP 2017-04-01
#
#                                                Comments  Year  MonthName  \
# 0             4/17/2021  Memorial opened to the public.  2021      April
# 1     Park closed for 16 days due to government shut...  2013    October
# 2             Sep 16: lost power due to Hurricane Ike.   2008  September
# 3     Park was closed from December 22 - December 31...  2018   December
# 4     May 10-11: 4,300 Boy & Girl Scouts participate...  2008       June
# ...                                                 ...   ...        ...
# 1585  We've only had a couple icy/frosty mornings so...  2017   December
# 1586  It seems like we've been busy and had quite a ...  2017    October
# 1587  June 1-12 were counted as the rest of the scho...  2005       June
# 1588  The biggest factor impacting our visitation th...  2017     August
# 1589  We've been having about 5 people each day comi...  2017      April
#
#       MonthNumber                                             Prompt  \
# 0               4  Comment for April:\n4/17/2021  Memorial opened...
# 1              10  Comment for October:\nPark closed for 16 days ...
# 2               9  Comment for September:\nSep 16: lost power due...
# 3              12  Comment for December:\nPark was closed from De...
# 4               6  Comment for June:\nMay 10-11: 4,300 Boy & Girl...
# ...           ...                                                ...
# 1585           12  Comment for December:\nWe've only had a couple...
# 1586           10  Comment for October:\nIt seems like we've been...
# 1587            6  Comment for June:\nJune 1-12 were counted as t...
# 1588            8  Comment for August:\nThe biggest factor impact...
# 1589            4  Comment for April:\nWe've been having about 5 ...
#
#       WordCount  TokenCount  CharacterCount  \
# 0             9          17              60
# 1            12          15              72
# 2            11          16              64
# 3            15          19              85
# 4            14          25              82
# ...         ...         ...             ...
# 1585         68          88             367
# 1586         68          89             390
# 1587         75          94             416
# 1588        125         154             680
# 1589        129         160             703
#
#                                                  Output
# 0                                   April: No Closures.
# 1     October: Park closed for 16 days due to govern...
# 2                               September: No Closures.
# 3     December: Park was closed from December 22 - D...
# 4                                    June: No Closures.
# ...                                                 ...
# 1585                             December: No Closures.
# 1586                              October: No Closures.
# 1587                                 June: No Closures.
# 1588                               August: No Closures.
# 1589                                April: No Closures.
#
# [1590 rows x 12 columns]

# %% [markdown]
# # Convert Output to JSONL

# %%
output_df = pd.read_csv('TrainData/output.csv')

# %%
# concatenate openai prompt with comments and ouput in this format "prompt\nInput:\n<comment>\nOutput:\n<output>"
output_df_filt = output_df.copy()
output_df_filt['JSON'] = output_df.apply(lambda x: f"### INSTRUCTION:\n{openai_prompt}\n\n### INPUT:\n{x['Prompt']}\n\n### OUTPUT:\n{x['Output']}\n### END", axis=1)
output_df_filt['JSON'] = output_df.apply(lambda x: f"Input:{x['Prompt']}Output:{x['Output']}", axis=1)
display(output_df_filt)
# Out:
#      UnitCode              ParkName        Date  \
# 0        WWIM  World War I Memorial  2021-04-01
# 1        LIBO  Lincoln Boyhood NMEM  2013-10-01
# 2        LIBO  Lincoln Boyhood NMEM  2008-09-01
# 3        LIBO  Lincoln Boyhood NMEM  2018-12-01
# 4        LIBO  Lincoln Boyhood NMEM  2008-06-01
# ...       ...                   ...         ...
# 1585     LEWI     Lewis & Clark NHP  2017-12-01
# 1586     LEWI     Lewis & Clark NHP  2017-10-01
# 1587     LEWI     Lewis & Clark NHP  2005-06-01
# 1588     LEWI     Lewis & Clark NHP  2017-08-01
# 1589     LEWI     Lewis & Clark NHP  2017-04-01
#
#                                                Comments  Year  MonthName  \
# 0             4/17/2021  Memorial opened to the public.  2021      April
# 1     Park closed for 16 days due to government shut...  2013    October
# 2             Sep 16: lost power due to Hurricane Ike.   2008  September
# 3     Park was closed from December 22 - December 31...  2018   December
# 4     May 10-11: 4,300 Boy & Girl Scouts participate...  2008       June
# ...                                                 ...   ...        ...
# 1585  We've only had a couple icy/frosty mornings so...  2017   December
# 1586  It seems like we've been busy and had quite a ...  2017    October
# 1587  June 1-12 were counted as the rest of the scho...  2005       June
# 1588  The biggest factor impacting our visitation th...  2017     August
# 1589  We've been having about 5 people each day comi...  2017      April
#
#       MonthNumber                                             Prompt  \
# 0               4  Comment for April:\n4/17/2021  Memorial opened...
# 1              10  Comment for October:\nPark closed for 16 days ...
# 2               9  Comment for September:\nSep 16: lost power due...
# 3              12  Comment for December:\nPark was closed from De...
# 4               6  Comment for June:\nMay 10-11: 4,300 Boy & Girl...
# ...           ...                                                ...
# 1585           12  Comment for December:\nWe've only had a couple...
# 1586           10  Comment for October:\nIt seems like we've been...
# 1587            6  Comment for June:\nJune 1-12 were counted as t...
# 1588            8  Comment for August:\nThe biggest factor impact...
# 1589            4  Comment for April:\nWe've been having about 5 ...
#
#       WordCount  TokenCount  CharacterCount  \
# 0             9          17              60
# 1            12          15              72
# 2            11          16              64
# 3            15          19              85
# 4            14          25              82
# ...         ...         ...             ...
# 1585         68          88             367
# 1586         68          89             390
# 1587         75          94             416
# 1588        125         154             680
# 1589        129         160             703
#
#                                                  Output  \
# 0                                   April: No Closures.
# 1     October: Park closed for 16 days due to govern...
# 2                               September: No Closures.
# 3     December: Park was closed from December 22 - D...
# 4                                    June: No Closures.
# ...                                                 ...
# 1585                             December: No Closures.
# 1586                              October: No Closures.
# 1587                                 June: No Closures.
# 1588                               August: No Closures.
# 1589                                April: No Closures.
#
#                                                    JSON
# 0     Input:Comment for April:\n4/17/2021  Memorial ...
# 1     Input:Comment for October:\nPark closed for 16...
# 2     Input:Comment for September:\nSep 16: lost pow...
# 3     Input:Comment for December:\nPark was closed f...
# 4     Input:Comment for June:\nMay 10-11: 4,300 Boy ...
# ...                                                 ...
# 1585  Input:Comment for December:\nWe've only had a ...
# 1586  Input:Comment for October:\nIt seems like we'v...
# 1587  Input:Comment for June:\nJune 1-12 were counte...
# 1588  Input:Comment for August:\nThe biggest factor ...
# 1589  Input:Comment for April:\nWe've been having ab...
#
# [1590 rows x 13 columns]

# %%
n = output_df_filt.shape[0]
cutoff = int(n*0.75)

# %%
output_df_filt['TokenCount'][:].sum()
# Out:
# 63201

# %%
max(output_df_filt['JSON'].apply(lambda x: len(x)))
# Out:
# 1301

# %%
print(output_df_filt['JSON'][1])
# Out:
# Input:Comment for October:
# Park closed for 16 days due to government shutdown.Output:October: Park closed for 16 days due to government shutdown.

# %%
import jsonlines
n = output_df_filt.shape[0]
cutoff = int(n*0.75)
# Train data
with jsonlines.open("TrainData/Old/train.jsonl", mode='w') as writer:
    for index, row in output_df_filt.iloc[:cutoff].iterrows():
        line = row['JSON']
        writer.write({"text": line})
# Valid data
with jsonlines.open("TrainData/Old/valid.jsonl", mode='w') as writer:
    for index, row in output_df_filt.iloc[cutoff:].iterrows():
        line = row['JSON']
        writer.write({"text": line})

# %% [markdown]
# # Convert Model To Q4

# %% [markdown]
# python convert.py --hf-path meta-llama/Llama-2-13b-hf -q --mlx-path /Users/austinlackey/Documents/GitHub/llm-data-validation/Llama2-13B-Q4

# %% [markdown]
# # Finetune Llama3-8B

# %% [markdown]
# python lora.py --model /Users/austinlackey/Documents/GitHub/llm-data-validation/Quantized-Base-Models/LLama3-8B-Q4 \
#                --train \
#                --data /Users/austinlackey/Documents/GitHub/llm-data-validation/TrainData \
#                --iters 1000 \
#                --max-tokens 150 \
#                --temp 0.3 \
#                --batch-size 2 \
#                --lora-layers 16
#
# python lora.py --model /Users/austinlackey/Documents/GitHub/llm-data-validation/Quantized-Base-Models/LLama3-8B-Q4 \
#                --adapter-file /Users/austinlackey/Documents/GitHub/llm-data-validation/Llama-3-adapters/adapters5.npz \
#                --max-tokens 100 \
#                --prompt ""

# %% [markdown]
# python lora.py --model /Users/austinlackey/Documents/GitHub/llm-data-validation/Quantized-Base-Models/LLama3-8B-Q4 \
#                --train \
#                --data /Users/austinlackey/Documents/GitHub/llm-data-validation/TrainData/Old \
#                --iters 1000 \
#                --max-tokens 100 \
#                --temp 0.3 \
#                --batch-size 1 \
#                --lora-layers 4
#
# python lora.py --model /Users/austinlackey/Documents/GitHub/llm-data-validation/Quantized-Base-Models/LLama3-8B-Q4 \
#                --adapter-file /Users/austinlackey/Documents/GitHub/llm-data-validation/Llama-3-adapters/adapters5.npz \
#                --max-tokens 100 \
#                --prompt ""

# %% [markdown]
# # Fuse

# %% [markdown]
# python fuse.py --model /Users/austinlackey/Documents/GitHub/llm-data-validation/Quantized-Base-Models/LLama3-8B-Q4 \
#                 --adapter-file /Users/austinlackey/Documents/GitHub/llm-data-validation/Llama-3-adapters/adapters1.npz \
#                 --save-path /Users/austinlackey/Documents/GitHub/llm-data-validation/Finetuned-Models/Llama-3-8B-NPSClosures-v1
